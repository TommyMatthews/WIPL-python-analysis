# %% [markdown]
# # MIRKLBG dielectric

# %%
import numpy as np

# %%
m = (35-40)/(np.log10(9.0)-np.log10(6.7))
m
# Out:
# np.float64(-39.011386933851746)

# %%
40 + m*(np.log10(94.0)-np.log10(6.7))
# Out:
# np.float64(-4.7481304022710376)

# %% [markdown]
# # Chitin dielectric

# %%
m = (7.4-6.6)/(4-6)
m
# Out:
# -0.40000000000000036

# %%
7.4+ m*(np.log10(35e9)-4)
# Out:
# np.float64(4.782372782259888)

# %% [markdown]
# # Chitin loss factor

# %%
m = (0.035-0.065)/(4-6)
m
# Out:
# 0.015

# %%
0.035+ m*(np.log10(35e9)-4)
# Out:
# np.float64(0.13316102066525415)
